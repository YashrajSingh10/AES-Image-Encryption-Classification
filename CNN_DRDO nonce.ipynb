# %%
import os
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim

from torch.utils.data import Dataset,DataLoader
from torchvision import transforms

from Crypto.Cipher import AES
from Crypto.Util.Padding import pad
from Crypto.Util import Counter

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report

device=torch.device(
    "cuda"
    if torch.cuda.is_available()
    else "cpu"
)

print(device)

if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# cuda
# NVIDIA GeForce RTX 3050 Laptop GPU

# %%
DATASET_PATH=r"C:\Users\Yashraj Singh\OneDrive\Desktop\archive\seg_train\seg_train"

IMAGE_SIZE=150

BATCH_SIZE=64

EPOCHS=20

LEARNING_RATE=0.0001

AES_KEY=b"1234567890ABCDEF"

# %%
image_paths=[]

for root,dirs,files in os.walk(DATASET_PATH):

    for file in files:

        if file.endswith(".jpg"):

            image_paths.append(
                os.path.join(
                    root,
                    file
                )
            )

print("Images =",len(image_paths))
# Out:
# Images = 14034

# %%
print("Using Images =",len(image_paths))
# Out:
# Using Images = 14034

# %%
import os

def encrypt_ctr(image_array):

    image_bytes=image_array.tobytes()

    nonce=os.urandom(8)

    cipher=AES.new(
        AES_KEY,
        AES.MODE_CTR,
        nonce=nonce
    )

    encrypted=cipher.encrypt(
        image_bytes
    )

    encrypted=np.frombuffer(
        encrypted[:image_array.size],
        dtype=np.uint8
    )

    encrypted=encrypted.reshape(
        image_array.shape
    )

    return encrypted

# %%
def encrypt_cbc(image_array):

    image_bytes=image_array.tobytes()

    iv=b"1234567890ABCDEF"

    cipher=AES.new(
        AES_KEY,
        AES.MODE_CBC,
        iv
    )

    encrypted=cipher.encrypt(
        pad(
            image_bytes,
            AES.block_size
        )
    )

    encrypted=np.frombuffer(
        encrypted[:image_array.size],
        dtype=np.uint8
    )

    encrypted=encrypted.reshape(
        image_array.shape
    )

    return encrypted

# %%
img=np.array(
    Image.open(
        image_paths[0]
    ).resize(
        (IMAGE_SIZE,IMAGE_SIZE)
    )
)

cbc=encrypt_cbc(img)

ctr=encrypt_ctr(img)

plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.imshow(img)
plt.title("Original")

plt.subplot(1,3,2)
plt.imshow(cbc)
plt.title("CBC")

plt.subplot(1,3,3)
plt.imshow(ctr)
plt.title("CTR")

plt.show()

# %%
train_paths,val_paths=train_test_split(
    image_paths,
    test_size=0.2,
    random_state=42
)

print(len(train_paths))
print(len(val_paths))
# Out:
# 11227
# 2807

# %%
class AESDataset(Dataset):

    def __init__(
        self,
        image_paths
    ):

        self.image_paths=image_paths

        self.transform=transforms.Compose([
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.RandomRotation(10)
        ])

    def __len__(self):

        return len(self.image_paths)*2

    def __getitem__(self,index):

        image_index=index//2

        class_label=index%2

        path=self.image_paths[
            image_index
        ]

        img=Image.open(path)

        img=img.convert("RGB")

        img=img.resize(
            (
                IMAGE_SIZE,
                IMAGE_SIZE
            )
        )

        img=self.transform(img)

        img=np.array(img)

        if class_label==0:

            img=encrypt_cbc(img)

        else:

            img=encrypt_ctr(img)

        img=img.astype(np.float32)

        img=img/255.0

        img=torch.tensor(
            img,
            dtype=torch.float32
        )

        img=img.permute(
            2,
            0,
            1
        )

        return img,class_label

# %%
train_dataset=AESDataset(
    train_paths
)

val_dataset=AESDataset(
    val_paths
)

print(len(train_dataset))
print(len(val_dataset))
# Out:
# 22454
# 5614

# %%
train_loader=DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=0
)

val_loader=DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=0
)

print("DataLoaders Created")
# Out:
# DataLoaders Created

# %%
images,labels=next(
    iter(train_loader)
)

print(images.shape)
print(labels.shape)
# Out:
# torch.Size([64, 3, 150, 150])
# torch.Size([64])

# %%
class CNN(nn.Module):

    def __init__(self):

        super().__init__()

        self.features=nn.Sequential(

            nn.Conv2d(
                3,
                32,
                3,
                padding=1
            ),

            nn.ReLU(),

            nn.MaxPool2d(2),

            nn.Conv2d(
                32,
                64,
                3,
                padding=1
            ),

            nn.ReLU(),

            nn.MaxPool2d(2),

            nn.Conv2d(
                64,
                128,
                3,
                padding=1
            ),

            nn.ReLU(),

            nn.MaxPool2d(2),

            nn.Conv2d(
                128,
                256,
                3,
                padding=1
            ),

            nn.ReLU(),

            nn.MaxPool2d(2)
        )

        self.classifier=nn.Sequential(

            nn.Flatten(),

            nn.Linear(
                256*9*9,
                512
            ),

            nn.ReLU(),

            nn.Linear(
                512,
                2
            )
        )

    def forward(self,x):

        x=self.features(x)

        x=self.classifier(x)

        return x

# %%
model=CNN().to(device)

criterion=nn.CrossEntropyLoss()

optimizer=optim.Adam(
    model.parameters(),
    lr=LEARNING_RATE
)

print(
    next(
        model.parameters()
    ).device
)
# Out:
# cuda:0

# %%
train_losses=[]
val_losses=[]

print("Starting Training")

for epoch in range(EPOCHS):

    model.train()

    train_loss=0

    for images,labels in train_loader:

        images=images.to(device)

        labels=labels.to(device)

        optimizer.zero_grad()

        outputs=model(images)

        loss=criterion(
            outputs,
            labels
        )

        loss.backward()

        optimizer.step()

        train_loss+=loss.item()

    train_loss/=len(train_loader)

    train_losses.append(
        train_loss
    )

    model.eval()

    val_loss=0

    correct=0

    total=0

    with torch.no_grad():

        for images,labels in val_loader:

            images=images.to(device)

            labels=labels.to(device)

            outputs=model(images)

            loss=criterion(
                outputs,
                labels
            )

            val_loss+=loss.item()

            _,predicted=torch.max(
                outputs,
                1
            )

            total+=labels.size(0)

            correct+=(
                predicted==labels
            ).sum().item()

    val_loss/=len(val_loader)

    val_losses.append(
        val_loss
    )

    accuracy=100*correct/total

    print(
        f"Epoch {epoch+1}/{EPOCHS} "
        f"Train Loss:{train_loss:.4f} "
        f"Val Loss:{val_loss:.4f} "
        f"Val Accuracy:{accuracy:.2f}%"
    )
# Out:
# Starting Training
# Epoch 1/20 Train Loss:0.6934 Val Loss:0.6930 Val Accuracy:50.00%
# Epoch 2/20 Train Loss:0.4693 Val Loss:0.3385 Val Accuracy:86.41%
# Epoch 3/20 Train Loss:0.3310 Val Loss:0.3343 Val Accuracy:86.66%
# Epoch 4/20 Train Loss:0.3187 Val Loss:0.3133 Val Accuracy:87.89%
# Epoch 5/20 Train Loss:0.3137 Val Loss:0.3061 Val Accuracy:88.12%
# Epoch 6/20 Train Loss:0.3088 Val Loss:0.3114 Val Accuracy:87.89%
# Epoch 7/20 Train Loss:0.3123 Val Loss:0.3155 Val Accuracy:87.73%
# Epoch 8/20 Train Loss:0.3127 Val Loss:0.3085 Val Accuracy:88.42%
# Epoch 9/20 Train Loss:0.3101 Val Loss:0.3010 Val Accuracy:88.42%
# Epoch 10/20 Train Loss:0.3086 Val Loss:0.3038 Val Accuracy:88.15%
# Epoch 11/20 Train Loss:0.3144 Val Loss:0.3154 Val Accuracy:88.05%
# Epoch 12/20 Train Loss:0.3128 Val Loss:0.3073 Val Accuracy:88.01%
# Epoch 13/20 Train Loss:0.3077 Val Loss:0.3200 Val Accuracy:87.32%
# Epoch 14/20 Train Loss:0.3020 Val Loss:0.3158 Val Accuracy:87.34%
# Epoch 15/20 Train Loss:0.3053 Val Loss:0.3180 Val Accuracy:87.92%
# Epoch 16/20 Train Loss:0.3091 Val Loss:0.2922 Val Accuracy:88.81%
# Epoch 17/20 Train Loss:0.3070 Val Loss:0.3161 Val Accuracy:87.37%
# Epoch 18/20 Train Loss:0.3073 Val Loss:0.2994 Val Accuracy:88.33%
# Epoch 19/20 Train Loss:0.3043 Val Loss:0.3015 Val Accuracy:88.35%
# Epoch 20/20 Train Loss:0.3065 Val Loss:0.3033 Val Accuracy:88.14%

# %%
all_preds=[]
all_labels=[]

model.eval()

with torch.no_grad():

    for images,labels in val_loader:

        images=images.to(device)

        outputs=model(images)

        _,preds=torch.max(
            outputs,
            1
        )

        all_preds.extend(
            preds.cpu().numpy()
        )

        all_labels.extend(
            labels.numpy()
        )

cm=confusion_matrix(
    all_labels,
    all_preds
)

print(cm)

print(
    classification_report(
        all_labels,
        all_preds,
        target_names=[
            "CBC",
            "CTR"
        ]
    )
)
# Out:
# [[2162  645]
#  [   2 2805]]
#               precision    recall  f1-score   support
#
#          CBC       1.00      0.77      0.87      2807
#          CTR       0.81      1.00      0.90      2807
#
#     accuracy                           0.88      5614
#    macro avg       0.91      0.88      0.88      5614
# weighted avg       0.91      0.88      0.88      5614

# %%
plt.figure(figsize=(8,5))

plt.plot(
    train_losses,
    label="Train"
)

plt.plot(
    val_losses,
    label="Validation"
)

plt.xlabel("Epoch")

plt.ylabel("Loss")

plt.legend()

plt.show()

# %%
torch.save(
    model.state_dict(),
    "intel_aes_classifier.pth"
)
